# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
data = pd.read_csv("heart.csv")

# Show first 5 rows
print("🔹 Head of the Data:")
print(data.head())

# Shape of data
print("\n🔹 Shape of Data (rows, columns):")
print(data.shape)

# Show column names
print("\n🔹 Column Names:")
print(data.columns.tolist())

# Check for null values
print("\n🔹 Null Values per Column:")
print(data.isnull().sum())

# Show value counts for 'sex' column
print("\n🔹 Value Counts for 'sex' Column (1 = Male, 0 = Female):")
print(data['sex'].value_counts())

# ✅ Boxplot: 'trestbps'
sns.boxplot(x=data['trestbps'])
plt.title("trestbps checking")
plt.show()

filtered_trestbps = data[data['trestbps'] <= 170]
sns.boxplot(x=filtered_trestbps['trestbps'])
plt.title("Box Plot: trestbps (≤ 170)")
plt.show()

# ✅ Boxplot: 'age'
plt.boxplot(x=data['age'])
plt.show()

# ✅ Bar Plot: Sex vs Max Heart Rate (thalach) — no warnings
plt.figure(figsize=(8, 5))
sns.barplot(x='sex', y='thalach', data=data, errorbar=None, hue='sex', palette="Set2", legend=False)
plt.title("Bar Plot: Sex vs Max Heart Rate (thalach)")
plt.xlabel("Sex (0 = Female, 1 = Male)")
plt.ylabel("Max Heart Rate (thalach)")
plt.show()
# Out:
# 🔹 Head of the Data:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0
#
# 🔹 Shape of Data (rows, columns):
# (1025, 14)
#
# 🔹 Column Names:
# ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
#
# 🔹 Null Values per Column:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# ...
